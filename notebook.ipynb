# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
import json

# %%
with open('data.json', 'r') as file:
    data = json.load(file)

# %%
factors = [item['factor'] for item in data]
timestamps = [datetime.fromisoformat(item['time']) for item in data]

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(timestamps, factors)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation=45)

ax.set_xlabel('Time')
ax.set_ylabel('Factor Value')
ax.set_title('Factor Value Over Time')

plt.tight_layout()
plt.show()

# %%
factors = [item['pi'] for item in data]
timestamps = [datetime.fromisoformat(item['time']) for item in data]

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(timestamps, factors)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation=45)

ax.set_xlabel('Time')
ax.set_ylabel('Pi Value')
ax.set_title('Pi Value Over Time')

plt.tight_layout()
plt.show()
